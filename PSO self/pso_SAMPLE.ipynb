# %%
import numpy as np
import matplotlib.pyplot as plt
import io
import pandas as pd
import sys
from sklearn import svm
from mpl_toolkits.mplot3d import axes3d, Axes3D

# %%
""""from google.colab import files
uploaded = files.upload()  can be used in collab"""
# Out:
# '"from google.colab import files\nuploaded = files.upload()  can be used in collab'

# %%
data = pd.read_csv('petrol.txt')
data.plot()
# Out:
# <Axes: >

# %%
len(data)
# Out:
# 192

# %%
#Normalizing the data

data_n = data.copy()
data_n = (data - data.min())/(data.max() - data.min())
print(data_n)
# Out:
#             X
# 0    0.004763
# 1    0.000000
# 2    0.056511
# 3    0.066516
# 4    0.158110
# ..        ...
# 187  0.933289
# 188  0.891503
# 189  0.891503
# 190  0.774339
# 191  0.832590
#
# [192 rows x 1 columns]

# %%
#check for repeating series later
#for now use lag function for period check , let the dimension be 15 for the time being
dimensions = 12
data_cn = pd.concat([data_n.shift(i) for i in range(0 + dimensions + 1)], axis = 1)

print(data_cn)
# Out:
#             X         X         X         X         X         X         X  \
# 0    0.004763       NaN       NaN       NaN       NaN       NaN       NaN
# 1    0.000000  0.004763       NaN       NaN       NaN       NaN       NaN
# 2    0.056511  0.000000  0.004763       NaN       NaN       NaN       NaN
# 3    0.066516  0.056511  0.000000  0.004763       NaN       NaN       NaN
# 4    0.158110  0.066516  0.056511  0.000000  0.004763       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 187  0.933289  1.000000  0.924214  0.930160  0.720555  0.645497  0.620743
# 188  0.891503  0.933289  1.000000  0.924214  0.930160  0.720555  0.645497
# 189  0.891503  0.891503  0.933289  1.000000  0.924214  0.930160  0.720555
# 190  0.774339  0.891503  0.891503  0.933289  1.000000  0.924214  0.930160
# 191  0.832590  0.774339  0.891503  0.891503  0.933289  1.000000  0.924214
#
#             X         X         X         X         X         X
# 0         NaN       NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN       NaN
# 3         NaN       NaN       NaN       NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...
# 187  0.663405  0.770778  0.744184  0.865780  0.709563  0.994610
# 188  0.620743  0.663405  0.770778  0.744184  0.865780  0.709563
# 189  0.645497  0.620743  0.663405  0.770778  0.744184  0.865780
# 190  0.720555  0.645497  0.620743  0.663405  0.770778  0.744184
# 191  0.930160  0.720555  0.645497  0.620743  0.663405  0.770778
#
# [192 rows x 13 columns]

# %%
# Splitting the data into train, validation and test

from sklearn.model_selection import train_test_split

X = data_cn.iloc[12:,1:]

y = data_cn.iloc[12:,0]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.4, shuffle = False)

X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size = 0.5, shuffle = False)


print(len(y_val))
print(len(y_test))
print(len(y_train))
# Out:
# 36
# 36
# 108

# %%
def pso(n_particles, iterations, dimensions, inertia):

    # Range of SVR's hyperparameters (Particles' search space)
    # C, Epsilon and Gamma
    max_c = 1e4
    min_c = 1e-3
    max_e = 1e-1
    min_e = 1e-8
    max_g = 1e3
    min_g = 1e-3
    
    # Initializing particles' positions randomly, inside
    # the search space
    x = np.random.rand(n_particles, 1)*(max_c - min_c) + min_c
    y = np.random.rand(n_particles, 1)*(max_e - min_e) + min_e
    z = np.random.rand(n_particles, 1)*(max_g - min_g) + min_g

    c = np.concatenate((x,y,z), axis=1)

    # Initializing particles' parameters
    v = np.zeros((n_particles, dimensions))
    c1 = 2
    c2 = 2
    p_best = np.zeros((n_particles, dimensions))
    p_best_val = np.zeros(n_particles) + sys.maxsize  
    g_best = np.zeros(dimensions)
    g_best_val = sys.maxsize

    best_iter = np.zeros(iterations)

    # Initializing regression variables
    p_best_RGS = np.empty((n_particles), dtype = object);
    g_best_RGS = sys.maxsize

    

    # Displaying tridimensional search space
    plot(c)

    from sklearn.metrics import mean_squared_error
    
    for i in range(iterations):

        for j in range(n_particles):
          # Starting Regression
          rgs = svm.SVR(C = c[j][0], epsilon = c[j][1], gamma = c[j][2])

          # Fitting the curve
          rgs.fit(X_train, y_train)
          y_predict = rgs.predict(X_val)

          # Using Mean Squared Error to verify prediction accuracy
          mse = mean_squared_error(y_val, y_predict) 

          # If mse value for that search point, for that particle,
          # is less than its personal best point,
          # replace personal best
          if(mse < p_best_val[j]):   # mse < p_best_val[j]
              # The value below represents the current least Mean Squared Error
              p_best_val[j] = mse
              
              p_best_RGS[j] = rgs
                           

              # The value below represents the current search coordinates for
              # the particle's current least Mean Squared Error found
              p_best[j] = c[j].copy()
              
          # Using auxiliar variable to get the index of the
          # particle that found the configuration with the 
          # minimum MSE value
          aux = np.argmin(p_best_val)        
        
          if(p_best_val[aux] < g_best_val):
              # Assigning Particle's current best MSE to the Group's best    
              g_best_val = p_best_val[aux]

              # Assigning Particle's current best configuration to the Group's best
              g_best = p_best[aux].copy()

              # Group best regressor:
              # the combination of C, Epsilon and Gamma
              # that computes the best fitting curve
              g_best_RGS = p_best_RGS[aux]

        
          rand1 = np.random.random()
          rand2 = np.random.random()

          # The variable below influences directly the particle's velocity.
          # It can either make it smaller or bigger. 
          w = inertia

          # The equation below represents Particle's velocity, which is
          # the rate of change in its position
          v[j] = w*v[j] + c1*(p_best[j] - c[j])*rand1 + c2*(g_best - c[j])*rand2

          # Change in the Particle's position 
          c[j] = c[j] + v[j]

          # Below is a series of conditions that stop the particles from
          # leaving the search space
          if(c[j][2] < min_g):
            c[j][2] = min_g
          if(c[j][2] > max_g):
            c[j][2] = max_g
          if(c[j][1] < min_e):
            c[j][1] = min_e
          if(c[j][1] > max_e):
            c[j][1] = max_e
          if(c[j][0] < min_c):
            c[j][0] = min_c
          if(c[j][0] > max_c):
            c[j][0] = max_c
            
     
        # The variable below represents the least Mean Squared Error
        # of the current iteration
        best_iter[i] = g_best_val
                
        print('Best value iteration # %d = %f\n'%(i, g_best_val))

    # Coordinates found after all the iterations
    print('Group Best configuration found: ')
    print(g_best)
    print('\n')
    print('Best Regressor:\n')
    print(g_best_RGS)
    print('\n')
    # Displaying the MSE value variation throughout the iterations
    t = range(iterations)
    plt.plot(t, best_iter, label='Fitness Value')
    plt.legend()
    plt.show()

    # Displaying Particles' final configuration
    plot(c)

    # Making the prediction with the best configuration of C, Epsilon and
    # Gamma found by the particles
    predict_test = g_best_RGS.predict(X_test)

    
    # Displaying actual values and predicted values for
    # Group's best configuration found overall
    print(color.BOLD + 'Predictions with the Population Best Value found:\n' + color.END)
    evaluate(predict_test)

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
# Function that displays tridimensional plot
def plot(some_list):
 
  ax = Axes3D(plt.figure())
  ax.scatter3D(some_list[:,0], some_list[:,1], some_list[:,2], color = 'r')
  ax.set_xlabel('$C$', fontsize = 20)
  ax.set_ylabel('$\epsilon$', fontsize = 25)
  ax.zaxis.set_rotate_label(False) 
  ax.set_zlabel('$\gamma$', fontsize=30, rotation = 0)
  ax.zaxis._axinfo['label']['space_factor'] = 1.0
  plt.show()

  print('\n')
  print('\n')

# %%
def evaluate(predictions):

    from sklearn.metrics import mean_squared_error
    import statistics as st

    predict_test = predictions

    # To un-normalize the data:
    # Multiply the values by
    # data.to_numpy().max()

    plt.plot(range(len(y_test)), y_test, label='Real')
    plt.plot(range(len(predict_test)), predict_test, label='Predicted')
    plt.legend()
    plt.show()
    
    mse = mean_squared_error(y_test, predict_test)
    print('\n')
    print('\n')
    print('Mean Squared Error for the Test Set:\t %f' %mse)
    print('\n')
    print('\n')
    print('Predictions Average:\t %f' %((predict_test.sum()/len(predict_test))))
    print('\n')
    print('\n')
    print('Predictions Median:\t %f' %(st.median(predict_test)))
    print('\n')
    print('\n')

# %%
pso(120, 100, 3, 1)
# Out:
# Best value iteration # 0 = 0.061898
#
# Best value iteration # 1 = 0.001443
#
# Best value iteration # 2 = 0.001443
#
# Best value iteration # 3 = 0.001443
#
# Best value iteration # 4 = 0.001443
#
# Best value iteration # 5 = 0.001443
#
# Best value iteration # 6 = 0.001437
#
# Best value iteration # 7 = 0.001433
#
# Best value iteration # 8 = 0.001433
#
# Best value iteration # 9 = 0.001433
#
# Best value iteration # 10 = 0.001433
#
# Best value iteration # 11 = 0.001433
#
# Best value iteration # 12 = 0.001433
#
# Best value iteration # 13 = 0.001433
#
# Best value iteration # 14 = 0.001433
#
# Best value iteration # 15 = 0.001433
#
# Best value iteration # 16 = 0.001433
#
# Best value iteration # 17 = 0.001433
#
# Best value iteration # 18 = 0.001433
#
# Best value iteration # 19 = 0.001433
#
# Best value iteration # 20 = 0.001433
#
# Best value iteration # 21 = 0.001433
#
# Best value iteration # 22 = 0.001433
#
# Best value iteration # 23 = 0.001433
#
# Best value iteration # 24 = 0.001433
#
# Best value iteration # 25 = 0.001433
#
# Best value iteration # 26 = 0.001433
#
# Best value iteration # 27 = 0.001433
#
# Best value iteration # 28 = 0.001433
#
# Best value iteration # 29 = 0.001433
#
# Best value iteration # 30 = 0.001433
#
# Best value iteration # 31 = 0.001433
#
# Best value iteration # 32 = 0.001433
#
# Best value iteration # 33 = 0.001433
#
# Best value iteration # 34 = 0.001433
#
# Best value iteration # 35 = 0.001433
#
# Best value iteration # 36 = 0.001433
#
# Best value iteration # 37 = 0.001433
#
# Best value iteration # 38 = 0.001433
#
# Best value iteration # 39 = 0.001433
#
# Best value iteration # 40 = 0.001433
#
# Best value iteration # 41 = 0.001433
#
# Best value iteration # 42 = 0.001433
#
# Best value iteration # 43 = 0.001433
#
# Best value iteration # 44 = 0.001433
#
# Best value iteration # 45 = 0.001433
#
# Best value iteration # 46 = 0.001433
#
# Best value iteration # 47 = 0.001433
#
# Best value iteration # 48 = 0.001433
#
# Best value iteration # 49 = 0.001433
#
# Best value iteration # 50 = 0.001433
#
# Best value iteration # 51 = 0.001433
#
# Best value iteration # 52 = 0.001433
#
# Best value iteration # 53 = 0.001433
#
# Best value iteration # 54 = 0.001433
#
# Best value iteration # 55 = 0.001433
#
# Best value iteration # 56 = 0.001433
#
# Best value iteration # 57 = 0.001433
#
# Best value iteration # 58 = 0.001433
#
# Best value iteration # 59 = 0.001433
#
# Best value iteration # 60 = 0.001433
#
# Best value iteration # 61 = 0.001433
#
# Best value iteration # 62 = 0.001433
#
# Best value iteration # 63 = 0.001433
#
# Best value iteration # 64 = 0.001433
#
# Best value iteration # 65 = 0.001433
#
# Best value iteration # 66 = 0.001433
#
# Best value iteration # 67 = 0.001433
#
# Best value iteration # 68 = 0.001433
#
# Best value iteration # 69 = 0.001433
#
# Best value iteration # 70 = 0.001433
#
# Best value iteration # 71 = 0.001433
#
# Best value iteration # 72 = 0.001433
#
# Best value iteration # 73 = 0.001433
#
# Best value iteration # 74 = 0.001433
#
# Best value iteration # 75 = 0.001433
#
# Best value iteration # 76 = 0.001433
#
# Best value iteration # 77 = 0.001433
#
# Best value iteration # 78 = 0.001433
#
# Best value iteration # 79 = 0.001433
#
# Best value iteration # 80 = 0.001433
#
# Best value iteration # 81 = 0.001433
#
# Best value iteration # 82 = 0.001433
#
# Best value iteration # 83 = 0.001433
#
# Best value iteration # 84 = 0.001433
#
# Best value iteration # 85 = 0.001433
#
# Best value iteration # 86 = 0.001433
#
# Best value iteration # 87 = 0.001433
#
# Best value iteration # 88 = 0.001433
#
# Best value iteration # 89 = 0.001433
#
# Best value iteration # 90 = 0.001433
#
# Best value iteration # 91 = 0.001433
#
# Best value iteration # 92 = 0.001433
#
# Best value iteration # 93 = 0.001433
#
# Best value iteration # 94 = 0.001433
#
# Best value iteration # 95 = 0.001433
#
# Best value iteration # 96 = 0.001433
#
# Best value iteration # 97 = 0.001433
#
# Best value iteration # 98 = 0.001433
#
# Best value iteration # 99 = 0.001433
#
# Group Best configuration found:
# [1.28360132e+02 1.00000000e-08 1.00000000e-03]
#
#
# Best Regressor:
#
# SVR(C=128.36013210192436, epsilon=1e-08, gamma=0.001)
# Predictions with the Population Best Value found:
# Mean Squared Error for the Test Set:	 0.003869
#
#
#
#
# Predictions Average:	 0.798968
#
#
#
#
# Predictions Median:	 0.806061
